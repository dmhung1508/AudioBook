# %%
from vietvoicetts import synthesize

# %%
duration = synthesize(
    input(),
    "welcome.wav",
    gender="female",
    area="northern",
    group ="audiobook",
    emotion="serious"
)
# Out:
# Using cached model: /home/inres/.cache/vietvoicetts/model-bin.pt
# Using cached model: /home/inres/.cache/vietvoicetts/model-bin.pt
# Selected sample #92 with gender: female, group: audiobook, area: northern, emotion: serious
# Using cached model: /home/inres/.cache/vietvoicetts/model-bin.pt
# chunk_text: 6 chunks: [119, 133, 81, 74, 113, 134]. Max chars: 145
# ...
# chunk_text: 2 chunks: [78, 54]. Max chars: 101
# ...
# chunk_text: 2 chunks: [97, 37]. Max chars: 100
# Long text detected (total estimated 50.4s), split into 8 chunks
# Reference audio: 6.6s, available per chunk: 7.4s (with 1.0s safety margin)
# Chunk 1/8: 119 chars, total duration 14.3s (ref: 6.6s + target: 7.7s). Content: Hai hôm sau. Trên con đường chạy ra ga Bắc Ninh với hai dãy cây um tùm đứng giàn hai bên, một chiếc ô tô hàng đứng chờ,
# Chunk 2/8: 78 chars, total duration 11.5s (ref: 6.6s + target: 4.9s). Content: mấy cái xe cao su lượn nghênh ngang, lùng khách., Anh Vân rảo bước đi bên tôi,
# ...

# %%
from vietvoicetts import synthesize

# Clone voice from reference audio
duration = synthesize(
    input(),
    "cloned_voice.wav",
    reference_audio="/home/inres/Desktop/Hung/VietVoice-TTS/test.mp3",
    reference_text="để thực hiện các công việc tình toán hay xử lý dữ liệu thì cần có các chương trình được gọi là chương trình ứng dụng. Có thể kể đến một số các chương trình ứng dụng."
)
# Out:
# Using cached model: /home/inres/.cache/vietvoicetts/model-bin.pt
# Using cached model: /home/inres/.cache/vietvoicetts/model-bin.pt
# Using reference audio and text: /home/inres/Desktop/Hung/VietVoice-TTS/test.mp3
# chunk_text: 8 chunks: [89, 79, 83, 81, 91, 97, 97, 37]. Max chars: 99
# ...
# chunk_text: 2 chunks: [47, 44]. Max chars: 64
# ...
# chunk_text: 3 chunks: [26, 62, 7]. Max chars: 69
# ...
# chunk_text: 2 chunks: [39, 57]. Max chars: 68
# Long text detected (total estimated 46.7s), split into 12 chunks
# Reference audio: 9.7s, available per chunk: 4.3s (with 1.0s safety margin)
# Chunk 1/12: 89 chars, total duration 14.4s (ref: 9.7s + target: 4.7s). Content: Hai hôm sau. Trên con đường chạy ra ga Bắc Ninh với hai dãy cây um tùm đứng giàn hai bên,
# Chunk 2/12: 79 chars, total duration 14.0s (ref: 9.7s + target: 4.3s). Content: một chiếc ô tô hàng đứng chờ, mấy cái xe cao su lượn nghênh ngang, lùng khách.,
# ...
